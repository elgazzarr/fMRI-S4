# %% [markdown]
# # Script to create list of file paths for one specific processing step + series of labels in same order

# %% [markdown]
# ### Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re #for sorting

# %% [markdown]
# ### Block executes the following:

# %% [markdown]
# ### Create subject lists for each of the three TR folders (Output folders RESTplus):

# %%
#Natural, ascending human sorting

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

#--------------------------------------------
directory = '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/REST'
subjects2=[]

for sub in os.listdir(directory):
    subjects2.append(sub)  #unordered
#-----------   
    
directory = '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/REST'
subjects2_7=[]

for sub in os.listdir(directory):
    subjects2_7.append(sub)  #unordered
#-----------   
 
directory = '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_5/REST'
subjects2_5=[]

for sub in os.listdir(directory):
    subjects2_5.append(sub)  #unordered
    
#-----------   

subjects=[]
subjects.extend(subjects2)
subjects.extend(subjects2_7)
subjects.extend(subjects2_5)

#sort naturally with increasing numbers
subjects.sort(key = natural_keys)

# %% [markdown]
# ## Processing Steps Overview:
#  - RESTT : First timepoints removed <br>
#  - RESTTR : Realigned <br>
#  - RESTTRW : Normalized to MNI space <br>
# <br>
#  - RESTTRWS : Smoothed <br>
#  - RESTTRWSC : Covariate removal <br>
#  - RESTTRWSCF : Bandpass filtering <br>
# <br>
#  - RESTTRWC : Covariate removal without prior smoothing <br>
#  - RESTTRWCF ' Bandpass filtering withou prior smoothing <br>

# %% [markdown]
# ### Selct processing step:

# %%
# Custom define to access other processing steps
proc_step = "RESTTRW"

'''
Example path:
"/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/RESTTRW/sub-0236/WRsub-0236_task-rest_bold.nii"
'''
proc_prefix = "WR"  
proc_suffix = "_task-rest_bold"

# %%
norm_mni_nifti_files = []

base_folder = "/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data"
# One folder per TR group:
folder2 = f"{base_folder}/TR_2"
folder2_5 = f"{base_folder}/TR_2_5"
folder2_7 = f"{base_folder}/TR_2_7"


for subject in subjects2:
    sub_normalizedMNI_path = f"{folder2}/Results/RESTTRW/{subject}/{proc_prefix}{subject}{proc_suffix}.nii"
    norm_mni_nifti_files.append(sub_normalizedMNI_path)
    
for subject in subjects2_7:
    sub_normalizedMNI_path = f"{folder2_7}/Results/RESTTRW/{subject}/{proc_prefix}{subject}{proc_suffix}.nii"
    norm_mni_nifti_files.append(sub_normalizedMNI_path)
    
for subject in subjects2_5:
    sub_normalizedMNI_path = f"{folder2_5}/Results/RESTTRW/{subject}/{proc_prefix}{subject}{proc_suffix}.nii"
    norm_mni_nifti_files.append(sub_normalizedMNI_path)
    
#sort naturally with increasing numbers
norm_mni_nifti_files.sort(key = natural_keys)

# %%
norm_mni_nifti_files
#In same order as "subjects"
# Out:
# ['/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0236/WRsub-0236_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0237/WRsub-0237_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0238/WRsub-0238_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0239/WRsub-0239_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0240/WRsub-0240_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0241/WRsub-0241_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0242/WRsub-0242_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0243/WRsub-0243_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0244/WRsub-0244_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0245/WRsub-0245_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0246/WRsub-0246_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0247/WRsub-0247_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0248/WRsub-0248_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0249/WRsub-0249_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0250/WRsub-0250_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0251/WRsub-0251_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0252/WRsub-0252_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0253/WRsub-0253_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0254/WRsub-0254_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0255/WRsub-0255_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0256/WRsub-0256_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0257/WRsub-0257_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0258/WRsub-0258_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0259/WRsub-0259_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-0260/WRsub-0260_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2/Results/RESTTRW/sub-
task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0470/WRsub-0470_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0471/WRsub-0471_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0472/WRsub-0472_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0473/WRsub-0473_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0474/WRsub-0474_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0475/WRsub-0475_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0476/WRsub-0476_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0477/WRsub-0477_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0478/WRsub-0478_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0479/WRsub-0479_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0480/WRsub-0480_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0481/WRsub-0481_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0482/WRsub-0482_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0483/WRsub-0483_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0484/WRsub-0484_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0485/WRsub-0485_task-rest_bold.nii',
#  '/dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2_7/Results/RESTTRW/sub-0486/WRsub-0486_task-rest_bold.nii']

# %% [markdown]
# ## Load additional information to create list with labels

# %%
os.chdir('/dbstore/Japanese_SRPBS_MDD_dataset/info_dataset/')

participants = pd.read_csv('participants/participants.csv') #contains all patient info w/out supplement

sup2_MDD = pd.read_csv('participants/sup2.csv')  # Contains MDD patients and controls + BDI-II information

# %%
import pandas as pd 
import numpy as np
from nilearn import input_data
from nilearn import datasets
from nilearn.input_data import NiftiLabelsMasker
import glob
from tqdm import tqdm
from nilearn.connectome import ConnectivityMeasure
import os
# Out:
# /data_local/softwares/anaconda3/envs/PGT/lib/python3.9/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
y_diag = []

for sub in subjects:
    sub_row = sup2_MDD.loc[sup2_MDD['participants_id'] == sub] 
    sub_diag = sub_row['diag']
    if int(sub_diag) == 2:
        y_diag.append(1) #MDD
    elif int(sub_diag) == 0:
        y_diag.append(0) #Healthy control
 
    
# Convert list to series
y = pd.Series(y_diag)

# %%
df = sup2_MDD
df = df.assign(tc_file="",cc_file="", mni_file="")

# %%
df
# Out:
#     participants_id site  diag  age  sex  hand  BDI-II tc_file cc_file  \
# 0          sub-0236  HUH     0   39    1     1     0.0
# 1          sub-0237  HUH     2   63    1     1    37.0
# 2          sub-0238  HUH     0   25    2     1     3.0
# 3          sub-0239  HUH     2   37    1     1    18.0
# 4          sub-0240  HUH     0   48    1     1     4.0
# ..              ...  ...   ...  ...  ...   ...     ...     ...     ...
# 441        sub-1017  COI     2   35    1     2    20.0
# 442        sub-1018  COI     2   39    2     1    34.0
# 443        sub-1019  COI     2   45    2     1    11.0
# 444        sub-1020  COI     2   27    1     1    50.0
# 445        sub-1295  COI     2   57    2     1    20.0
#
#     mni_file
# 0
# 1
# 2
# 3
# 4
# ..       ...
# 441
# 442
# 443
# 444
# 445
#
# [446 rows x 10 columns]

# %%
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm', symmetric_split= True)
atlas_filename = dataset.maps
labels = dataset.labels[1:]
masker_cor = NiftiLabelsMasker(labels_img=atlas_filename, standardize=True, verbose=0)

# create masker for HO subcortical
dataset = datasets.fetch_atlas_harvard_oxford('sub-maxprob-thr25-2mm', symmetric_split= True)
atlas_filename = dataset.maps
labels_s = dataset.labels[1:]

masker_sub = NiftiLabelsMasker(labels_img=atlas_filename, standardize=True, verbose=0)

# %%
output_path = '/data_local/deeplearning/Datasets/Japs_MDD_pr/'
atlas_name = 'HO'

for file in tqdm(files):
    file = file.replace('Results', '')
    sub = file.split('/')[-2]
    sub_path = output_path + sub + '/' + atlas_name + '/'
    save_path =output_path + sub + '/'  + 'ATLAS'
    
    if not os.path.isdir(sub_path):
        os.makedirs(sub_path)
 
    mni_path = file
    tc_path = sub_path +'tc.npy'
    cc_path = sub_path+'cc.npy'
    
    df.loc[df['participants_id'] == sub,'tc_file'] = tc_path
    df.loc[df['participants_id'] == sub, 'cc_file'] = cc_path
    df.loc[df['participants_id'] == sub, 'mni_file'] = mni_path
    # extract timeseries and concatenate them
    time_series_c = masker_cor.fit_transform(file)
    time_series_s = masker_sub.fit_transform(file)
    tc = np.concatenate((time_series_c,time_series_s), 1)



    correlation_measure = ConnectivityMeasure(kind='correlation')
    cc = correlation_measure.fit_transform([tc])[0]

    np.save(tc_path,tc)
    np.save(cc_path,cc)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 446/446 [22:42<00:00,  3.05s/it]

# %%
tc.shape
# Out:
# (97, 118)

# %%
print(file)df
# Out:
# /dbstore/Japanese_SRPBS_MDD_dataset/restplus_data/TR_2//RESTTRW/sub-0236/WRsub-0236_task-rest_bold.nii

# %%
from glob import glob

filess= '/dbstore/Jap_ah/*/*'
files = glob(filess)[1:]

# %%
df
# Out:
#     participants_id site  diag  age  sex  hand  BDI-II  \
# 0          sub-0236  HUH     0   39    1     1     0.0
# 1          sub-0237  HUH     2   63    1     1    37.0
# 2          sub-0238  HUH     0   25    2     1     3.0
# 3          sub-0239  HUH     2   37    1     1    18.0
# 4          sub-0240  HUH     0   48    1     1     4.0
# ..              ...  ...   ...  ...  ...   ...     ...
# 441        sub-1017  COI     2   35    1     2    20.0
# 442        sub-1018  COI     2   39    2     1    34.0
# 443        sub-1019  COI     2   45    2     1    11.0
# 444        sub-1020  COI     2   27    1     1    50.0
# 445        sub-1295  COI     2   57    2     1    20.0
#
#                                                tc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                                cc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                               mni_file
# 0    /dbstore/Jap_ah/sub-0236/SWRsub-0236_task-rest...
# 1    /dbstore/Jap_ah/sub-0237/SWRsub-0237_task-rest...
# 2    /dbstore/Jap_ah/sub-0238/SWRsub-0238_task-rest...
# 3    /dbstore/Jap_ah/sub-0239/SWRsub-0239_task-rest...
# 4    /dbstore/Jap_ah/sub-0240/SWRsub-0240_task-rest...
# ..                                                 ...
# 441  /dbstore/Jap_ah/sub-1017/SWRsub-1017_task-rest...
# 442  /dbstore/Jap_ah/sub-1018/SWRsub-1018_task-rest...
# 443  /dbstore/Jap_ah/sub-1019/SWRsub-1019_task-rest...
# 444  /dbstore/Jap_ah/sub-1020/SWRsub-1020_task-rest...
# 445  /dbstore/Jap_ah/sub-1295/SWRsub-1295_task-rest...
#
# [446 rows x 10 columns]

# %%
df.diag.replace({2:1}, inplace=True)
df
# Out:
#     participants_id site  diag  age  sex  hand  BDI-II  \
# 0          sub-0236  HUH     0   39    1     1     0.0
# 1          sub-0237  HUH     1   63    1     1    37.0
# 2          sub-0238  HUH     0   25    2     1     3.0
# 3          sub-0239  HUH     1   37    1     1    18.0
# 4          sub-0240  HUH     0   48    1     1     4.0
# ..              ...  ...   ...  ...  ...   ...     ...
# 441        sub-1017  COI     1   35    1     2    20.0
# 442        sub-1018  COI     1   39    2     1    34.0
# 443        sub-1019  COI     1   45    2     1    11.0
# 444        sub-1020  COI     1   27    1     1    50.0
# 445        sub-1295  COI     1   57    2     1    20.0
#
#                                                tc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                                cc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                               mni_file
# 0    /dbstore/Jap_ah/sub-0236/SWRsub-0236_task-rest...
# 1    /dbstore/Jap_ah/sub-0237/SWRsub-0237_task-rest...
# 2    /dbstore/Jap_ah/sub-0238/SWRsub-0238_task-rest...
# 3    /dbstore/Jap_ah/sub-0239/SWRsub-0239_task-rest...
# 4    /dbstore/Jap_ah/sub-0240/SWRsub-0240_task-rest...
# ..                                                 ...
# 441  /dbstore/Jap_ah/sub-1017/SWRsub-1017_task-rest...
# 442  /dbstore/Jap_ah/sub-1018/SWRsub-1018_task-rest...
# 443  /dbstore/Jap_ah/sub-1019/SWRsub-1019_task-rest...
# 444  /dbstore/Jap_ah/sub-1020/SWRsub-1020_task-rest...
# 445  /dbstore/Jap_ah/sub-1295/SWRsub-1295_task-rest...
#
# [446 rows x 10 columns]

# %%
df.rename(columns={'participants_id':'ID', 'diag':'Diagnosis', 'sex':'Sex'},inplace=True)
df
# Out:
#            ID site  Diagnosis  age  Sex  hand  BDI-II  \
# 0    sub-0236  HUH          0   39    1     1     0.0
# 1    sub-0237  HUH          1   63    1     1    37.0
# 2    sub-0238  HUH          0   25    2     1     3.0
# 3    sub-0239  HUH          1   37    1     1    18.0
# 4    sub-0240  HUH          0   48    1     1     4.0
# ..        ...  ...        ...  ...  ...   ...     ...
# 441  sub-1017  COI          1   35    1     2    20.0
# 442  sub-1018  COI          1   39    2     1    34.0
# 443  sub-1019  COI          1   45    2     1    11.0
# 444  sub-1020  COI          1   27    1     1    50.0
# 445  sub-1295  COI          1   57    2     1    20.0
#
#                                                tc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                                cc_file  \
# 0    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 1    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 2    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 3    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 4    /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# ..                                                 ...
# 441  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 442  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 443  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 444  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
# 445  /data_local/deeplearning/Datasets/Japs_MDD_pr/...
#
#                                               mni_file
# 0    /dbstore/Jap_ah/sub-0236/SWRsub-0236_task-rest...
# 1    /dbstore/Jap_ah/sub-0237/SWRsub-0237_task-rest...
# 2    /dbstore/Jap_ah/sub-0238/SWRsub-0238_task-rest...
# 3    /dbstore/Jap_ah/sub-0239/SWRsub-0239_task-rest...
# 4    /dbstore/Jap_ah/sub-0240/SWRsub-0240_task-rest...
# ..                                                 ...
# 441  /dbstore/Jap_ah/sub-1017/SWRsub-1017_task-rest...
# 442  /dbstore/Jap_ah/sub-1018/SWRsub-1018_task-rest...
# 443  /dbstore/Jap_ah/sub-1019/SWRsub-1019_task-rest...
# 444  /dbstore/Jap_ah/sub-1020/SWRsub-1020_task-rest...
# 445  /dbstore/Jap_ah/sub-1295/SWRsub-1295_task-rest...
#
# [446 rows x 10 columns]

# %%
df_test.Diagnosis.value_counts()
# Out:
# 0    54
# 1    36
# Name: Diagnosis, dtype: int64

# %%
df_healthy = df[df['Diagnosis'] == 0]
df_mdd = df[df['Diagnosis'] == 1 ]

# %%
len(df_mdd)
# Out:
# 177

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['Diagnosis'])

# %%
df_train.to_csv('/data/agelgazzar/projects/state-spaces/csvfiles/Jpmdd_train.csv')
df_test.to_csv('/data/agelgazzar/projects/state-spaces/csvfiles/Jpmdd_test.csv')

# %%
df = df.assign(nTime="")
for i in df.index:
    tc = np.load(df['tc_file'].loc[i].replace('ATLAS',atlas_name))
    ntime = tc.shape[0]
    df['nTime'].loc[i] = ntime
# Out:
# /data_local/softwares/anaconda3/envs/PGT/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.nTime.value_counts()
# Out:
# 230    194
# 133    189
# 97      62
# 274      1
# Name: nTime, dtype: int64
